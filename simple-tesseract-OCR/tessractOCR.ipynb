# %% [markdown]
# Installation of neccessary packages.

# %%
# !sudo apt install tesseract-ocr

# %%
# !pip install pytesseract

# %%
# !pip install opencv-python

# %% [markdown]
# Importing the installed packages.

# %%
import pytesseract
import cv2
import os
try:
 from PIL import Image
except ImportError:
 import Image

# %% [markdown]
# Images path for the OCR recognition..

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1b8f6e49-f69d-4775-832c-acd732a92422" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b8f6e49-f69d-4775-832c-acd732a92422">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving calibiri.jpg to calibiri.jpg

# %% [markdown]
# Base code for text recognition.

# %%
  from google.colab.patches import cv2_imshow
#Image reading
img = cv2.imread('calibiri.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Performing OTSU threshold
ret, thresh1 = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY |cv2.THRESH_OTSU)
cv2_imshow(thresh1)
cv2.waitKey()
image = Image.fromarray(thresh1)

# Text extraction
extractedInformation = pytesseract.image_to_string(image)
# Out:
# <PIL.Image.Image image mode=L size=550x338 at 0x7FBA280C9590>

# %% [markdown]
# Print Text information

# %%
print(extractedInformation)
# Out:
# Calibri
# ABCDabcd - Regular
# ABCDabcd - Bold
#
# ABCDabcd - Italic
# ABCDabcd - Bold Italic
